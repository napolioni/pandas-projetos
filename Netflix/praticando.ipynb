# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('netflix.csv')

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# director        2634
# country          831
# cast             825
# date_added        10
# rating             4
# duration           3
# show_id            0
# type               0
# title              0
# release_year       0
# listed_in          0
# description        0
# dtype: int64

# %%
# Tratando os valores nulos na coluna Director

data.director.fillna('Diretor nao informado', inplace=True)

# %%
data
# Out:
#      show_id     type                  title               director  \
# 0         s1    Movie   Dick Johnson Is Dead        Kirsten Johnson
# 1         s2  TV Show          Blood & Water  Diretor não informado
# 2         s3  TV Show              Ganglands        Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans  Diretor não informado
# 4         s5  TV Show           Kota Factory  Diretor não informado
# ...      ...      ...                    ...                    ...
# 8802   s8803    Movie                 Zodiac          David Fincher
# 8803   s8804  TV Show            Zombie Dumb  Diretor não informado
# 8804   s8805    Movie             Zombieland        Ruben Fleischer
# 8805   s8806    Movie                   Zoom           Peter Hewitt
# 8806   s8807    Movie                 Zubaan            Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
# Visualização dos filmes e shoes de Tv apenas com com diretores identificados

data[data.director != 'Diretor não informado']
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
data.head()
# Out:
#   show_id     type                  title               director  \
# 0      s1    Movie   Dick Johnson Is Dead        Kirsten Johnson
# 1      s2  TV Show          Blood & Water  Diretor não informado
# 2      s3  TV Show              Ganglands        Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Diretor não informado
# 4      s5  TV Show           Kota Factory  Diretor não informado
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
data['director'] = data['director'].str.replace('Não identificado', 'nulo')

# %%
data['director']
# Out:
# 0       Kirsten Johnson
# 1                  nulo
# 2       Julien Leclercq
# 3                  nulo
# 4                  nulo
#              ...
# 8802      David Fincher
# 8803               nulo
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
data[data.director == 'nulo'].count(drop=)
# Out:
# show_id         2634
# type            2634
# title           2634
# director        2634
# cast            2282
# country         2225
# date_added      2624
# release_year    2634
# rating          2631
# duration        2634
# listed_in       2634
# description     2634
# dtype: int64

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water             nulo
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             nulo
# 4         s5  TV Show           Kota Factory             nulo
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb             nulo
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data[data.director == 'nulo']
# Out:
#      show_id     type                                title director  \
# 1         s2  TV Show                        Blood & Water     nulo
# 3         s4  TV Show                Jailbirds New Orleans     nulo
# 4         s5  TV Show                         Kota Factory     nulo
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia     nulo
# 14       s15  TV Show      Crime Stories: India Detectives     nulo
# ...      ...      ...                                  ...      ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V     nulo
# 8796   s8797  TV Show                           Yunus Emre     nulo
# 8797   s8798  TV Show                            Zak Storm     nulo
# 8800   s8801  TV Show                   Zindagi Gulzar Hai     nulo
# 8803   s8804  TV Show                          Zombie Dumb     nulo
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
data[data.country == 'South Korea']
# Out:
#      show_id     type                        title       director  \
# 104     s105  TV Show          Tayo the Little Bus           nulo
# 124     s125  TV Show  Pororo - The Little Penguin           nulo
# 289     s290  TV Show            The Crowned Clown           nulo
# 456     s457  TV Show             Her Private Life           nulo
# 545     s546  TV Show         YooHoo to the Rescue           nulo
# ...      ...      ...                          ...            ...
# 8463   s8464    Movie       The President's Barber  Chan-sang Lim
# 8467   s8468    Movie                   The Prison       Na Hyeon
# 8575   s8576  TV Show              This Is My Love           nulo
# 8613   s8614    Movie               Train to Busan   Sang-ho Yeon
# 8684   s8685  TV Show                      Vroomiz           nulo
#
#                                                    cast      country  \
# 104                          Robyn Slade, Kami Desilets  South Korea
# ...

# %%
# 

data.groupby('type').count()
# Out:
#          show_id  title  director  cast  country  date_added  release_year  \
# type
# Movie       6131   6131      6131  5656     5691        6131          6131
# TV Show     2676   2676      2676  2326     2285        2666          2676
#
#          rating  duration  listed_in  description
# type
# Movie      6129      6128       6131         6131
# TV Show    2674      2676       2676         2676

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water             nulo
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans             nulo
# 4      s5  TV Show           Kota Factory             nulo
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
tvshow_estados_unidos = data[(data.country == 'United States') & (data.type == 'TV Show')].count()

# %%
tvshow_estados_unidos
# Out:
# show_id         760
# type            760
# title           760
# director         48
# cast            624
# country         760
# date_added      754
# release_year    760
# rating          760
# duration        760
# listed_in       760
# description     760
# dtype: int64
